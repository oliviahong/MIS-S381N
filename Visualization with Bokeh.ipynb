# %% [markdown]
# # Visualization with Bokeh
#
# This problem involves building an interactive visualization. Bokeh is a Python interactive visualization library that targets modern web browsers for presentation. Using the [King County House Sales](http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data-original) data, I built a Bokeh visualization which allows the user explore how price varies with living room size and year built. I created a visualization that allows the user to toggle the X axis of a scatter plot between living room size and year built, with the y-axis always being price. I also added the hover tool so that if the user hovers over a datapoint in the living-room-size plot a window pops up that shows year built - and vice versa.

# %%
import pandas as pd
from bokeh.layouts import column
from bokeh.models import CustomJS, ColumnDataSource, Select, HoverTool, BoxSelectTool, LinearAxis
from bokeh.plotting import Figure, output_notebook, show

df = pd.read_csv("kc_house_data.csv")

output_notebook()

source = ColumnDataSource(data=dict(x=df['sqft_living'], y=df['price'], z=df['yr_built']))
source2 = ColumnDataSource(data=dict(x1=df['sqft_living'], x2=df['yr_built']))

plot = Figure(plot_width=400, plot_height=400, tools="hover")
plot.scatter('x', 'y', source=source)
plot.yaxis.axis_label = "Price"
# create new x-axis and hide old one
plot.xaxis.visible = False
xaxis = LinearAxis(axis_label="Living Room Size")
plot.add_layout(xaxis, 'below')

plot.select(dict(type=HoverTool)).tooltips = {"Other X Value":"@z"}
callback = CustomJS(args=dict(source=source, source2=source2, xaxis=xaxis), code="""
        var data = source.get('data');
        var data2 = source2.get('data');
        var f = cb_obj.get('value')
        if (f=="Year Built"){
            data['x'] = data2['x2']
            data['z'] = data2['x1']
            xaxis.attributes.axis_label = "Year Built";
            xaxis.trigger('change');
            
        }
        if (f=="Living Room Size"){
            data['x'] = data2['x1']
            data['z'] = data2['x2']
            xaxis.attributes.axis_label = "Living Room Size";
            xaxis.trigger('change');
        }
        source.trigger('change');
    """)

slider = Select(title="Choose X:", value="Living Room Size", options=["Living Room Size", "Year Built"], callback=callback)

layout = column(slider, plot)

show(layout)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="a4a37aed-b919-48cc-8ea0-99e528f5bb2c">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="plotdiv" id="5b5779a8-1f28-4710-916d-2e1cf3af46aa"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#5b5779a8-1f28-4710-916d-2e1cf3af46aa").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5b5779a8-1f28-4710-916d-2e1cf3af46aa");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5b5779a8-1f28-4710-916d-2e1cf3af46aa' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"f4dae7a8-aa7e-446b-8271-ed60bf0d6723":{"roots":{"references":[{"attributes":{"formatter":{"id":"85e0d54c-6f4f-48f9-a7b1-a5ad7aaadff8","type":"BasicTickFormatter"},"plot":{"id":"6e5e04d9-7424-490d-a531-595c863e48d8","subtype":"Figure","type":"Plot"},"ticker":{"id":"71d5398a-1eee-4505-9270-0ad3d54e5dfb","type":"BasicTicker"},"visible":false},"id":"d17edd72-8bb2-44d6-b08b-18876ac821a4","type":"LinearAxis"},{"attributes":{"children":[{"id":"54a17319-e9f7-4463-a86a-744ddc5255ba","type":"WidgetBox"},{"id":"6e5e04d9-7424-490d-a531-595c863e48d8","subtype":"Figure","type":"Plot"}]},"id":"0166a360-ec2c-4404-bfa9-7f39e4d3ccaa","type":"Column"},{"attributes":{"below":[{"id":"d17edd72-8bb2-44d6-b08b-18876ac821a4","type":"LinearAxis"},{"id":"e599279a-949f-4102-9c8c-c06785f60b92","type":"LinearAxis"}],"left":[{"id":"c9b06f33-5eab-4f06-81a2-5ded2d1cbc8f","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"d17edd72-8bb2-44d6-b08b-18876ac821a4","type":"LinearAxis"},{"id":"65474c91-f614-4d46-ab23-7f7fe2352ecb","type":"Grid"},{"id":"c9b06f33-5eab-4f06-81a2-5ded2d1cbc8f","type":"LinearAxis"},{"id":"7c048cbe-8477-45ba-8278-110a64d2265f","type":"Grid"},{"id":"7fdb8a89-88fd-402c-9487-d014ff6515b2","type":"GlyphRenderer"},{"id":"e599279a-949f-4102-9c8c-c06785f60b92","type":"LinearAxis"}],"title":{"id":"fa06f7de-0370-4226-90a5-e754706d1321","type":"Title"},"tool_events":{"id":"23f6889b-8402-4215-b19e-804a6a2a3a85","type":"ToolEvents"},"toolbar":{"id":"fe56fc1c-0bfe-4ea7-b37d-8217383d2d37","type":"Toolbar"},"x_range":{"id":"cd1b17c5-886e-4f44-b465-1a9385258bdf","type":"DataRange1d"},"y_range":{"id":"48d51f94-e366-43ad-91e1-f04e5eb4338e","type":"DataRange1d"}},"id":"6e5e04d9-7424-490d-a531-595c863e48d8","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"a20edea8-52a6-4ddc-a316-cd2bd0075bf0","type":"BasicTicker"},{"attributes":{},"id":"85e0d54c-6f4f-48f9-a7b1-a5ad7aaadff8","type":"BasicTickFormatter"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"9b00e4d8-3457-44dc-a5d9-d8983488453b","type":"HoverTool"}]},"id":"fe56fc1c-0bfe-4ea7-b37d-8217383d2d37","type":"Toolbar"},{"attributes":{"callback":null},"id":"48d51f94-e366-43ad-91e1-f04e5eb4338e","type":"DataRange1d"},{"attributes":{"plot":null,"text":null},"id":"fa06f7de-0370-4226-90a5-e754706d1321","type":"Title"},{"attributes":{"data_source":{"id":"4213b967-d79f-435a-9c29-1de8cd30f9c4","type":"ColumnDataSource"},"glyph":{"id":"3f1ac847-7aec-4e7d-b1ea-1baa5485eee9","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"93590a92-d3aa-46d3-bed4-77549c5792a9","type":"Circle"},"selection_glyph":null},"id":"7fdb8a89-88fd-402c-9487-d014ff6515b2","type":"GlyphRenderer"},{"attributes":{"args":{"source":{"id":"4213b967-d79f-435a-9c29-1de8cd30f9c4","type":"ColumnDataSource"},"source2":{"id":"f0752179-1521-4f23-9992-be5097016b45","type":"ColumnDataSource"},"xaxis":{"id":"e599279a-949f-4102-9c8c-c06785f60b92","type":"LinearAxis"}},"code":"\n        var data = source.get('data');\n        var data2 = source2.get('data');\n        var f = cb_obj.get('value')\n        if (f==\"Year Built\"){\n            data['x'] = data2['x2']\n            data['z'] = data2['x1']\n            xaxis.attributes.axis_label = \"Year Built\";\n            xaxis.trigger('change');\n            \n        }\n        if (f==\"Living Room Size\"){\n            data['x'] = data2['x1']\n            data['z'] = data2['x2']\n            xaxis.attributes.axis_label = \"Living Room Size\";\n            xaxis.trigger('change');\n        }\n        source.trigger('change');\n    "},"id":"b3cfbae1-7c52-46af-9c82-a6e6f93cdf8a","type":"CustomJS"},{"attributes":{"callback":{"id":"b3cfbae1-7c52-46af-9c82-a6e6f93cdf8a","type":"CustomJS"},"options":["Living Room Size","Year Built"],"title":"Choose X:","value":"Living Room Size"},"id":"138b1bbc-4819-42e0-bf66-4cd83e835888","type":"Select"},{"attributes":{"callback":null,"plot":{"id":"6e5e04d9-7424- ...
